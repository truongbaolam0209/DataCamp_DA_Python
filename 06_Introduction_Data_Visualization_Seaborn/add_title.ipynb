# %%
import pandas as pd
import numpy as np
from numpy import median

import matplotlib.pyplot as plt
import seaborn as sns
from empiricaldist import Pmf

from IPython.display import display, HTML

display(HTML(
    '<style>'
        '#notebook { padding-top: 0px !important; } ' 
        '.container { width: 100% !important; } '
        '.end_space { min-height: 0px !important; } '
        'table, tr, td { border: 1px  black solid !important; color: black; }'
        'th { border: 1px  black solid !important; color: #130f40; background: #ECFED7; }'
    '</style>'
))
# Out:
# <style>#notebook { padding-top: 0px !important; } .container { width: 100% !important; } .end_space { min-height: 0px !important; } table, tr, td { border: 1px  black solid !important; color: black; }th { border: 1px  black solid !important; color: #130f40; background: #ECFED7; }</style>

# %%
# cotw = pd.read_csv(r'C:\000_TBL\001 DATA ANALYSIS\DATACAMP\PYTHON\ProjectFiles\06_Introduction_Data_Visualization_Seaborn\Datasets\countries-of-the-world.csv')
student_data = pd.read_csv(r'C:\000_TBL\001 DATA ANALYSIS\DATACAMP\PYTHON\ProjectFiles\06_Introduction_Data_Visualization_Seaborn\Datasets\student-alcohol-consumption.csv')
survey_data = pd.read_csv(r'C:\000_TBL\001 DATA ANALYSIS\DATACAMP\PYTHON\ProjectFiles\06_Introduction_Data_Visualization_Seaborn\Datasets\young-people-survey-responses.csv')
mpg = pd.read_csv(r'C:\000_TBL\001 DATA ANALYSIS\DATACAMP\PYTHON\ProjectFiles\06_Introduction_Data_Visualization_Seaborn\Datasets\mpg.csv')

# %%
# Create scatter plot
g = sns.relplot(x="weight", 
                y="horsepower", 
                data=mpg,
                kind="scatter")

# Identify plot type
type_of_g = type(g)

# Print type
print(type_of_g)
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %%
# Create scatter plot
g = sns.relplot(x="weight", 
                y="horsepower", 
                data=mpg,
                kind="scatter")

# Add a title "Car Weight vs. Horsepower"
g.fig.suptitle("Car Weight vs. Horsepower")

# Show plot
plt.show()

# %%
# # Create line plot
# g = sns.lineplot(x="model_year", y="mpg_mean", 
#                  data=mpg,
#                  hue="origin")

# # Add a title "Average MPG Over Time"
# g.set_title("Average MPG Over Time")

# # Show plot
# plt.show()

# %%
# # Create line plot
# g = sns.lineplot(x="model_year", y="mpg_mean", 
#                  data=mpg_mean,
#                  hue="origin")

# # Add a title "Average MPG Over Time"
# g.set_title("Average MPG Over Time")

# # Add x-axis and y-axis labels
# g.set(xlabel="Car Model Year", 
#       ylabel="Average MPG")

# # Show plot
# plt.show()

# %%
display(mpg)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# mpg_mean = mpg.groupby(['model_year', 'origin']).agg({'mpg': ['mean']}).rename(columns={'mean':'mpg_mean'}).unstack()

mpg_mean = mpg.groupby(['model_year', 'origin']).agg({'mpg': ['mean']})

mpg_mean.columns = ['_'.join(col) for col in mpg_mean.columns]

mpg_mean = mpg_mean.reset_index()

display(mpg_mean)
display(mpg_mean.columns)
# Out:
#     model_year  origin   mpg_mean
# 0           70  europe  25.200000
# 1           70   japan  25.500000
# 2           70     usa  15.272727
# 3           71  europe  28.750000
# 4           71   japan  29.500000
# 5           71     usa  18.100000
# 6           72  europe  22.000000
# 7           72   japan  24.200000
# 8           72     usa  16.277778
# 9           73  europe  24.000000
# 10          73   japan  20.000000
# 11          73     usa  15.034483
# 12          74  europe  27.000000
# 13          74   japan  29.333333
# 14          74     usa  18.333333
# 15          75  europe  24.500000
# 16          75   japan  27.500000
# 17          75     usa  17.550000
# 18          76  europe  24.250000
# 19          76   japan  28.000000
# 20          76     usa  19.431818
# 21          77  europe  29.250000
# 22          77   japan  27.416667
# 23          77     usa  20.722222
# 24          78  europe  24.950000
# 25          78   japan  29.687500
# ...

# %%
# Create line plot
g = sns.lineplot(x="model_year", y="mpg_mean", 
                 data=mpg_mean,
                 hue="origin")

# Add a title "Average MPG Over Time"
g.set_title("Average MPG Over Time")

# Show plot
plt.show()

# %%
# Create line plot
g = sns.lineplot(x="model_year", y="mpg_mean", 
                 data=mpg_mean,
                 hue="origin")

# Add a title "Average MPG Over Time"
g.set_title("Average MPG Over Time")

# Add x-axis and y-axis labels
g.set(xlabel="Car Model Year", 
      ylabel="Average MPG")

# Show plot
plt.show()

# %%
# Create point plot
sns.catplot(x="origin", 
            y="acceleration", 
            data=mpg, 
            kind="point", 
            join=False, 
            capsize=0.1)

# Rotate x-tick labels
plt.xticks(rotation=90)

# Show plot
plt.show()

# %%
# Set palette to "Blues"
sns.set_palette("Blues")

# Adjust to add subgroups based on "Interested in Pets"
g = sns.catplot(x="Gender",
                y="Age", data=survey_data, 
                kind="box", hue="Pets")

# Set title to "Age of Those Interested in Pets vs. Not"
g.fig.suptitle("Age of Those Interested in Pets vs. Not")

# Show plot
plt.show()

# %%
# Set the figure style to "dark"
sns.set_style("dark")

# Adjust to add subplots per gender
g = sns.catplot(x="Village - town", y="Techno", 
                data=survey_data, kind="bar",
                col="Gender")

# Add title and axis labels
g.fig.suptitle("Percentage of Young People Who Like Techno", y=1.02)
g.set(xlabel="Location of Residence", 
      ylabel="% Who Like Techno")

# Show plot
plt.show()
