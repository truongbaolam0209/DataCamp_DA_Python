# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from empiricaldist import Pmf

from IPython.display import display, HTML

display(HTML(
    '<style>'
        '#notebook { padding-top: 0px !important; } ' 
        '.container { width: 100% !important; } '
        '.end_space { min-height: 0px !important; } '
        'table, tr, td { border: 1px  black solid !important; color: black; }'
        'th { border: 1px  black solid !important; color: #130f40; background: #b8e994; }'
    '</style>'
))
# Out:
# <style>#notebook { padding-top: 0px !important; } .container { width: 100% !important; } .end_space { min-height: 0px !important; } table, tr, td { border: 1px  black solid !important; color: black; }th { border: 1px  black solid !important; color: #130f40; background: #b8e994; }</style>

# %%
sp500 = pd.read_csv(r'C:\000_TBL\001 DATA ANALYSIS\DATACAMP\PYTHON\ProjectFiles\04_Joining_Data_With_Pandas\Datasets\S&P500.csv')
gdp = pd.read_csv(r'C:\000_TBL\001 DATA ANALYSIS\DATACAMP\PYTHON\ProjectFiles\04_Joining_Data_With_Pandas\Datasets\WorldBank_GDP.csv')
pop = pd.read_csv(r'C:\000_TBL\001 DATA ANALYSIS\DATACAMP\PYTHON\ProjectFiles\04_Joining_Data_With_Pandas\Datasets\WorldBank_POP.csv')

# %%
# display(sp500)
# display(gdp)

# Use merge_ordered() to merge gdp and sp500 on year and date
# gdp_sp500 = pd.merge_ordered(gdp, sp500, left_on='Year', right_on='Date', how='left', fill_method='ffill')
gdp_sp500 = pd.merge_ordered(gdp, sp500, left_on='Year', right_on='Date', how='left')


display(gdp_sp500)

# Subset the gdp and returns columns
gdp_returns = gdp_sp500[['GDP','Returns']]
display(gdp_returns)

# Print gdp_returns correlation
print(gdp_returns.corr())
# Out:
#      Country Name Country Code     Indicator Name  Year           GDP    Date  \
# 0           China          CHN  GDP (current US$)  2010  6.087160e+12  2010.0
# 1         Germany          DEU  GDP (current US$)  2010  3.417090e+12  2010.0
# 2           Japan          JPN  GDP (current US$)  2010  5.700100e+12  2010.0
# 3   United States          USA  GDP (current US$)  2010  1.499210e+13  2010.0
# 4           China          CHN  GDP (current US$)  2011  7.551500e+12  2011.0
# 5         Germany          DEU  GDP (current US$)  2011  3.757700e+12  2011.0
# 6           Japan          JPN  GDP (current US$)  2011  6.157460e+12  2011.0
# 7   United States          USA  GDP (current US$)  2011  1.554260e+13  2011.0
# 8           China          CHN  GDP (current US$)  2012  8.532230e+12  2012.0
# 9         Germany          DEU  GDP (current US$)  2012  3.543980e+12  2012.0
# 10          Japan          JPN  GDP (current US$)  2012  6.203210e+12  2012.0
# ...
