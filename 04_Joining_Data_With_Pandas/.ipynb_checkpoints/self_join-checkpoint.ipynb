# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from empiricaldist import Pmf

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_rows', 20)

from IPython.display import display, HTML

display(HTML(
    '<style>'
        '#notebook { padding-top: 0px !important; } ' 
        '.container { width: 100% !important; } '
        '.end_space { min-height: 0px !important; } '
        'table, tr, td { border: 1px  black solid !important; color: black; }'
        'th { border: 1px  black solid !important; color: #130f40; background: #E5FAE3; }'
    '</style>'
))
# Out:
# <style>#notebook { padding-top: 0px !important; } .container { width: 100% !important; } .end_space { min-height: 0px !important; } table, tr, td { border: 1px  black solid !important; color: black; }th { border: 1px  black solid !important; color: #130f40; background: #E5FAE3; }</style>

# %%
# SELF JOIN
# ID HERE IS MOVIE ID

# %%
crews = pd.read_pickle(r'C:\000_TBL\001 DATA ANALYSIS\DATACAMP\PYTHON\ProjectFiles\04_Joining_Data_With_Pandas\Datasets\crews.p')

# %%
display(crews)
display(crews[crews['id'] == 19995])
              
# Merge the crews table to itself
crews_self_merged = crews.merge(crews, on='id', how='inner', suffixes=('_dir','_crew'))
display(crews_self_merged)
# Create a Boolean index to select the appropriate rows
boolean_filter = ((crews_self_merged['job_dir'] == 'Director') & (crews_self_merged['job_crew'] != 'Director'))

display(boolean_filter)

direct_crews = crews_self_merged[boolean_filter]
display(direct_crews)
# Out:
#             id  department                 job               name
# 0        19995     Editing              Editor  Stephen E. Rivkin
# 2        19995       Sound      Sound Designer  Christopher Boyes
# 4        19995  Production             Casting          Mali Finn
# 6        19995   Directing            Director      James Cameron
# 7        19995     Writing              Writer      James Cameron
# ...        ...         ...                 ...                ...
# 129574  126186   Directing            Director        Daniel Hsia
# 129576   25975  Production  Executive Producer     Clark Peterson
# 129578   25975   Directing            Director   Brian Herzlinger
# 129579   25975   Directing            Director           Jon Gunn
# 129580   25975   Directing            Director         Brett Winn
#
# [42502 rows x 4 columns]
#         id         department                          job  \
# 0    19995            Editing                       Editor
# ...
